# %% [markdown]
# # Data loading

# %%
import os

os.chdir("/home/aneta/Desktop/GSN/code/edge-aware-face-autoencoder")

# %%
# !pwd
# Out:
# /home/aneta/Desktop/GSN/code/edge-aware-face-autoencoder

# %%
import matplotlib.pyplot as plt

from scripts.training import data_loading as dl

# %load_ext autoreload
# %autoreload 2

# %%
DATASET_PATH = os.path.join(os.getcwd(), "data", "dataset", "train")

# %%
dataset = dl.CelebAFaceAutoencoderDataset(dataset_root=DATASET_PATH)

# %%
img = dataset[48]

plt.imshow(img)

# %%
i = 1
for load_img in dataset:
    if i%250 == 0:
        print(i)
    i += 1
print(i)
# Out:
# 250
# 500
# 750
# 1000
# 1250
# 1500
# 1750
# 2000
# 2250
# 2500
# 2750
# 3000
# 3250
# 3500
# 3750
# 4000
# 4250
# 4500
# 4750
# 5000
# 5250
# 5500
# 5750
# 6000
# 6250
# 6500
# 6750
# 7000
# 7250
# 7500
# 7750
# 8000
# 8250
# 8500
# 8750
# 9000
# 9250
# 9500
# 9750
# 10000
# 10250
# 10500
# 10750
# 11000
# 11250
# 11500
# 11750
# 12000
# 12250
# 12500
# 12750
# 13000
# 13250
# 13500
# 13750
# 14000
# 14250
# 14500
# 14750
# 15000
# 15250
# 15500
# 15750
# 16000
# 16250
# 16500
# 16750
# 17000
# 17250
# 17500
# 17750
# 18000
# 18250
# 18500
# 18750
# 19000
# 19250
# 19500
# 19750
# 20000
# 20250
# 20500
# 20750
# 21000
# 21250
# 21500
# 21750
# 22000
# 22250
# 22500
# 22750
# 23000
# 23250
# 23500
# 23750
# 24000
# 24001

# %%
DATASET_PATH = os.path.join(os.getcwd(), "data", "dataset", "test")
dataset = dl.CelebAFaceAutoencoderDataset(dataset_root=DATASET_PATH)
i = 1
for load_img in dataset:
    if i%250 == 0:
        print(i)
    i += 1
print(i)
# Out:
# 250
# 500
# 750
# 1000
# 1250
# 1500
# 1750
# 2000
# 2250
# 2500
# 2750
# 3000
# 3001

# %%
DATASET_PATH = os.path.join(os.getcwd(), "data", "dataset", "val")
dataset = dl.CelebAFaceAutoencoderDataset(dataset_root=DATASET_PATH)
i = 1
for load_img in dataset:
    if i%250 == 0:
        print(i)
    i += 1
print(i)
# Out:
# 250
# 500
# 750
# 1000
# 1250
# 1500
# 1750
# 2000
# 2250
# 2500
# 2750
# 3000
# 3001
